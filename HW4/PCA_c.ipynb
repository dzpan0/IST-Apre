# %%
import matplotlib.pyplot as plt

ypos = [3.52700, 3.1234]
xpos = [3.44691, -3.6831]
yneg = [0.11620]
xneg = [0.55443]

plt.scatter(xpos, ypos, marker='o', label='positive (+)')
plt.scatter(xneg, yneg, marker='s', label='negative (-)')
plt.xlabel('PC1 (v3)')
plt.ylabel('PC2 (v2)')
plt.legend(loc='lower left')
plt.savefig("PCA.png")
